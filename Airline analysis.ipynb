# %%
#IMPORTING LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from matplotlib import cm
import warnings
warnings.filterwarnings('ignore')

# %%
#AIRLINE ANALYSIS

# %%
import pandas as pd
df=pd.read_csv(r"D:\Project\flight_data_BOM_BLR.csv")
df
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0   Air India     AI 621        Mumbai         03:55    Bengaluru
# 1     AirAsia     I5 670        Mumbai         19:55    Bengaluru
# 2     AirAsia    I5 2992        Mumbai         23:55    Bengaluru
# 3      IndiGo    6E 5388        Mumbai         21:30    Bengaluru
# 4   Akasa Air    QP 1103        Mumbai         00:45    Bengaluru
# ..        ...        ...           ...           ...          ...
# 85    Vistara     UK 840     Bengaluru         21:35       Mumbai
# 86    Vistara     UK 850     Bengaluru         19:55       Mumbai
# 87    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 88    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 89  Air India     AI 642     Bengaluru         21:25       Mumbai
#
#         ArrivingTime   Duration   Price
# 0              05:50  01 h 55 m   2,307
# 1              21:45  01 h 50 m   2,773
# 2   01:45\r\n+ 1 DAY  01 h 50 m   2,773
# ...

# %%
#DATA EXPLORATION

# %%
df.head()
# Out:
#   FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 0  Air India     AI 621        Mumbai         03:55    Bengaluru
# 1    AirAsia     I5 670        Mumbai         19:55    Bengaluru
# 2    AirAsia    I5 2992        Mumbai         23:55    Bengaluru
# 3     IndiGo    6E 5388        Mumbai         21:30    Bengaluru
# 4  Akasa Air    QP 1103        Mumbai         00:45    Bengaluru
#
#        ArrivingTime   Duration  Price
# 0             05:50  01 h 55 m  2,307
# 1             21:45  01 h 50 m  2,773
# 2  01:45\r\n+ 1 DAY  01 h 50 m  2,773
# 3             23:15  01 h 45 m  2,839
# 4             02:20  01 h 35 m  3,005

# %%
df.tail()
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 85    Vistara     UK 840     Bengaluru         21:35       Mumbai
# 86    Vistara     UK 850     Bengaluru         19:55       Mumbai
# 87    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 88    Vistara     UK 864     Bengaluru         19:00       Mumbai
# 89  Air India     AI 642     Bengaluru         21:25       Mumbai
#
#    ArrivingTime   Duration   Price
# 85        23:20  01 h 45 m  11,038
# 86        21:35  01 h 40 m  11,934
# 87        20:35  01 h 35 m  14,596
# 88        20:35  01 h 35 m  14,596
# 89        23:20  01 h 55 m  20,581

# %%
df.sample(10)
# Out:
#    FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# 61     IndiGo    6E 6347     Bengaluru         21:45       Mumbai
# 59  Akasa Air    QP 1104     Bengaluru         11:45       Mumbai
# 16     IndiGo    6E 5069        Mumbai         11:15    Bengaluru
# 79    Vistara     UK 866     Bengaluru         06:40       Mumbai
# 68     IndiGo    6E 5134     Bengaluru         13:45       Mumbai
# 20     IndiGo    6E 5125        Mumbai         23:15    Bengaluru
# 23     IndiGo    6E 6293        Mumbai         07:45    Bengaluru
# 45     IndiGo    6E 5295     Bengaluru         04:25       Mumbai
# 21  Akasa Air    QP 1110        Mumbai         09:25    Bengaluru
# 77  Air India     AI 610     Bengaluru         19:20       Mumbai
#
#         ArrivingTime   Duration  Price
# 61             23:40  01 h 55 m  4,400
# 59             13:30  01 h 45 m  4,249
# 16             13:00  01 h 45 m  3,650
# 79             08:20  01 h 40 m  9,346
# 68             15:20  01 h 35 m  4,900
# ...

# %%
df.dtypes
# Out:
# FlightName       object
# FlightCode       object
# DepartingCity    object
# DepartingTime    object
# ArrivingCity     object
# ArrivingTime     object
# Duration         object
# Price            object
# dtype: object

# %%
df.describe()
# Out:
#        FlightName FlightCode DepartingCity DepartingTime ArrivingCity  \
# count          90         90            90            90           90
# unique          5         70             2            58            2
# top        IndiGo    6E 5124     Bengaluru         09:20       Mumbai
# freq           39          3            46             3           46
#
#        ArrivingTime   Duration  Price
# count            90         90     90
# unique           61          9     53
# top           11:35  01 h 50 m  3,005
# freq              3         21      5

# %%
df.isnull().sum()
# Out:
# FlightName       0
# FlightCode       0
# DepartingCity    0
# DepartingTime    0
# ArrivingCity     0
# ArrivingTime     0
# Duration         0
# Price            0
# dtype: int64

# %%
#TARGET DISTRIBUTION

# %%
#define the figure
fig=plt.figure(figsize=(22,6))
plt.suptitle("TARGET DISTRIBUTION",weight='bold',fontsize=25,fontname='monospace')
grid=gridspec.GridSpec(nrows=1,ncols=2,figure=fig)
#create your first subplot byb defining axis
ax1=fig.add_subplot(grid[0,:1])
ax1.set_title('Satisfaction count')
#with the help of seaborn  we are drawing the countplot
sns.countplot(x='FlightName',data=df,ax=ax1,hue='FlightName')
ax1.set_xticklabels(df['FlightName'].value_counts().index,fontsize=15)

#second subplot
ax2=fig.add_subplot(grid[0,1:])
ax2.set_title('Target weight')
label=list(df['FlightName'].value_counts().index)
value=list(df['FlightName'].value_counts().values)
#pie chart
ax2.pie(value,labels=label,autopct='%1.1f%%',startangle=60)
ax2.axis('equal')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#ANALZING CUSTOMER PROFILE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec
from matplotlib import cm
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
df1=pd.read_csv(r"D:\Project\test.csv")
df1
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# ...

# %%
#DATA EXPLORATION

# %%
df1.head()
# Out:
#    Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0           0  19556  Female     Loyal Customer   52  Business travel
# 1           1  90035  Female     Loyal Customer   36  Business travel
# 2           2  12360    Male  disloyal Customer   20  Business travel
# 3           3  77959    Male     Loyal Customer   44  Business travel
# 4           4  36875  Female     Loyal Customer   49  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0       Eco              160                      5
# 1  Business             2863                      1
# 2       Eco              192                      2
# 3  Business             3377                      0
# 4       Eco             1182                      2
#
#    Departure/Arrival time convenient  ...  Inflight entertainment  \
# 0                                  4  ...                       5
# 1                                  1  ...                       4
# ...

# %%
df1.tail()
# Out:
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# 25975       25975  34799  Female     Loyal Customer   42  Personal Travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 25971  Business              526                      3
# 25972  Business              646                      4
# 25973       Eco              828                      2
# 25974  Business             1127                      3
# 25975       Eco              264                      2
#
#        Departure/Arrival time convenient  ...  Inflight entertainment  \
# 25971                                  3  ...                       4
# ...

# %%
df1.sample(10)
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 14809       14809   12951  Female     Loyal Customer   40  Personal Travel
# 10762       10762   89725  Female     Loyal Customer   58  Personal Travel
# 18778       18778   29966  Female  disloyal Customer   62  Business travel
# 63             63   26594    Male     Loyal Customer   66  Business travel
# 7359         7359  120872    Male     Loyal Customer   57  Business travel
# 7120         7120   56509    Male     Loyal Customer   44  Business travel
# 13672       13672   20369    Male     Loyal Customer   32  Personal Travel
# 19840       19840   30201  Female  disloyal Customer   27  Business travel
# 21762       21762   18213  Female  disloyal Customer   39  Business travel
# 5704         5704   29511    Male     Loyal Customer   42  Business travel
#
#           Class  Flight Distance  Inflight wifi service  \
# 14809       Eco              979                      1
# ...

# %%
df1.dtypes
# Out:
# Unnamed: 0                             int64
# id                                     int64
# Gender                                object
# Customer Type                         object
# Age                                    int64
# Type of Travel                        object
# Class                                 object
# Flight Distance                        int64
# Inflight wifi service                  int64
# Departure/Arrival time convenient      int64
# Ease of Online booking                 int64
# Gate location                          int64
# Food and drink                         int64
# Online boarding                        int64
# Seat comfort                           int64
# Inflight entertainment                 int64
# On-board service                       int64
# Leg room service                       int64
# Baggage handling                       int64
# Checkin service                        int64
# Inflight service                       int64
# ...

# %%
df1.describe()
# Out:
#          Unnamed: 0             id           Age  Flight Distance  \
# count  25976.000000   25976.000000  25976.000000     25976.000000
# mean   12987.500000   65005.657992     39.620958      1193.788459
# std     7498.769632   37611.526647     15.135685       998.683999
# min        0.000000      17.000000      7.000000        31.000000
# 25%     6493.750000   32170.500000     27.000000       414.000000
# 50%    12987.500000   65319.500000     40.000000       849.000000
# 75%    19481.250000   97584.250000     51.000000      1744.000000
# max    25975.000000  129877.000000     85.000000      4983.000000
#
#        Inflight wifi service  Departure/Arrival time convenient  \
# count           25976.000000                       25976.000000
# mean                2.724746                           3.046812
# std                 1.335384                           1.533371
# min                 0.000000                           0.000000
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                            0
# id                                    0
# Gender                                0
# Customer Type                         0
# Age                                   0
# Type of Travel                        0
# Class                                 0
# Flight Distance                       0
# Inflight wifi service                 0
# Departure/Arrival time convenient     0
# Ease of Online booking                0
# Gate location                         0
# Food and drink                        0
# Online boarding                       0
# Seat comfort                          0
# Inflight entertainment                0
# On-board service                      0
# Leg room service                      0
# Baggage handling                      0
# Checkin service                       0
# Inflight service                      0
# Cleanliness                           0
# Departure Delay in Minutes            0
# ...

# %%
#PASSENGER PROFILE

# %%
#define gender,type of travel,class,age of people
fig=plt.figure(figsize=(30,18))
plt.suptitle("PASSENGER PROFILE",weight='bold',fontsize=25,fontname='monospace')
grid=gridspec.GridSpec(nrows=2,ncols=2,figure=fig)

#create your first subplot by defining axis
ax1=fig.add_subplot(grid[0,:1])
ax1.set_title('Gender',fontsize=18)
label=list(df1['Gender'].value_counts().index)
value=list(df1['Gender'].value_counts().values)
#pie chart
ax1.pie(value,labels=label,autopct='%1.1f%%',startangle=90)
ax1.axis('equal')

#create your second subplot byb defining axis
ax2=fig.add_subplot(grid[0,1:])
ax2.set_title('Customer Type',fontsize=18)
label=list(df1['Customer Type'].value_counts().index)
value=list(df1['Customer Type'].value_counts().values)
#pie chart
ax2.pie(value,labels=label,autopct='%1.1f%%',startangle=90)
ax2.axis('equal')

#create your third subplot byb defining axis
ax3=fig.add_subplot(grid[1,:1])
ax3.set_title('Class',fontsize=18)
label=list(df1['Class'].value_counts().index)
value=list(df1['Class'].value_counts().values)
#pie chart
ax3.pie(value,labels=label,autopct='%1.1f%%',startangle=90)
ax3.axis('equal')

ax4=fig.add_subplot(grid[1,1:])
ax4.set_title('Age of Passengers',fontsize=18)
sns.kdeplot(df1['Age'],ax=ax4,fill=True)

#change the tick size
ax4.tick_params(axis='x',labelsize=20)
ax4.tick_params(axis='y',labelsize=20)

#change the label size
ax4.set_xlabel('Age of People',fontsize=20,weight='bold')
ax4.set_ylabel('Density',fontsize=20,weight='bold')
for spine in ax4.spines.values():
    spine.set_visible(False)
ax4.axvline(df1['Age'].mean(),linestyle='--',label='Average Age') 
ax4.legend(fontsize=20)
plt.show()

# %%
#PEOPLE SATISFACTION LEVEL

# %%
fig=plt.figure(figsize=(30,18))
#plt.suptitle("PASSENGER SATISFACTION LEVEL",weight='bold',fontsize=12,fontname='monospace')
grid=gridspec.GridSpec(nrows=2,ncols=2,figure=fig)
#create your third subplot byb defining axis
ax5=fig.add_subplot(grid[0,:1])
ax5.set_title('PASSENGER SATISFACTION LEVEL',fontsize=18)
sns.countplot(x=df1['Gender'],hue=df1['satisfaction'])

for p in ax5.patches:
    ax5.annotate('{:.1f}'.format(p.get_height()),(p.get_x()+0.1,p.get_height()+50),fontsize=20)
#off the y-axis
ax5.get_yaxis().set_visible(False)
ax5.tick_params(axis='x',labelsize=15)
ax5.set_xlabel('Gender',fontsize=20)
plt.show()

# %%
#OUTLIER DETECTION

# %%
np.percentile(df1['Flight Distance'],25)
np.percentile(df1['Flight Distance'],75)
iqr=np.percentile(df1['Flight Distance'],75)-np.percentile(df1['Flight Distance'],25)
lower_bound=np.percentile(df1['Flight Distance'],25)-(1.5*iqr)
upper_bound=np.percentile(df1['Flight Distance'],75)+(1.5*iqr)
print(lower_bound,upper_bound)
# Out:
# -1581.0 3739.0

# %%
fig,(ax1,ax2)=plt.subplots(1,2,figsize=(20,8))
plt.suptitle('Flight Distance Analysis',fontsize=24,weight='bold')
ax1.set_title('Box-Plot',fontsize=15)
sns.boxplot(y='Flight Distance',data=df1,ax=ax1)
ax1.set_ylabel('Flight Distance',fontsize=20)


#kde plot
ax2.set_title('KDE-Plot',fontsize=15)
sns.kdeplot(df1['Flight Distance'],ax=ax2,fill=True)
ax2.axvline(lower_bound, linestyle = '--',label='lower_bound')
ax2.axvline(upper_bound, linestyle = '--',label='upper_bound')
ax2.legend()
ax2.set_xlabel('Flight Distance',fontsize=20)
ax2.annotate(f'{upper_bound:.0f}', xy=(upper_bound, 0.0005), arrowprops=dict(arrowstyle="->", color='r', alpha=.8))
plt.show()

# %%
def percentile_at_first_view(data,col,start,end,jump):
    for i in range(start,end,jump):
        var=data[col].values
        var = np.sort(var,axis = None)
        print("{} percentile value is {}".format(i,var[int(len(var)*(float(i)/100))]))
    print("100 percentile value is ",var[-1])
percentile_at_first_view(df1,'Flight Distance',0,100,10)
# Out:
# 0 percentile value is 31
# 10 percentile value is 237
# 20 percentile value is 361
# 30 percentile value is 488
# 40 percentile value is 639
# 50 percentile value is 849
# 60 percentile value is 1048
# 70 percentile value is 1512
# 80 percentile value is 2084
# 90 percentile value is 2759
# 100 percentile value is  4983

# %%
def percentile_at_first_view(data,col,start,end,jump):
    for i in np.arange(0.0,1.0,0.1):
        var=data[col].values
        var = np.sort(var,axis = None)
        print("{} percentile value is {}".format(99+i,var[int(len(var)*(float(99+i)/100))]))
    print("100 percentile value is ",var[-1])
percentile_at_first_view(df1,'Flight Distance',91,100,1)
# Out:
# 99.0 percentile value is 3889
# 99.1 percentile value is 3902
# 99.2 percentile value is 3914
# 99.3 percentile value is 3927
# 99.4 percentile value is 3937
# 99.5 percentile value is 3951
# 99.6 percentile value is 3960
# 99.7 percentile value is 3973
# 99.8 percentile value is 3986
# 99.9 percentile value is 3997
# 100 percentile value is  4983

# %%
df1[df1['Flight Distance']>3995]
# Out:
#        Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 273           273   53258  Female     Loyal Customer   57  Business travel
# 1590         1590   94129  Female     Loyal Customer   42  Business travel
# 1961         1961    3326    Male     Loyal Customer   49  Business travel
# 3645         3645   59263    Male     Loyal Customer   44  Business travel
# 3795         3795   72042  Female     Loyal Customer   45  Personal Travel
# 3953         3953   59265    Male     Loyal Customer   44  Business travel
# 5608         5608   37499  Female     Loyal Customer   25  Business travel
# 7851         7851   31874  Female     Loyal Customer   33  Business travel
# 8023         8023   58403    Male     Loyal Customer   24  Business travel
# 11037       11037  107142    Male     Loyal Customer   41  Business travel
# 11779       11779   31816  Female     Loyal Customer   45  Personal Travel
# ...

# %%
def OutlierDetection(data,col):
    #iqr
    iqr=np.percentile(data[col],75)-np.percentile(data[col],25)
    lower_bound=np.percentile(data[col],25)-(1.5*iqr)
    upper_bound=np.percentile(data[col],75)+(1.5*iqr)
    #fig box and kde
    fig,(ax1,ax2) =plt.subplots(1,2,figsize=(20,8))
    plt.suptitle(col+' Analysis',fontsize=24,weight='bold')
    ax1.set_title('Box-Plot',fontsize=15)
    sns.boxplot(y=col,data=data,ax=ax1,flierprops={"marker": "x"})
    ax1.set_ylabel(col,fontsize=20)
    #kde plot
    ax2.set_title('KDE-Plot',fontsize=15)
    sns.kdeplot(df1[col],ax=ax2,fill=True)
    ax2.axvline(df1[col].mean(), linestyle = '--',label='Mean')
    ax2.axvline(df1[col].median(), linestyle = '--',label='Median')
    ax2.axvline(lower_bound, linestyle = '--',label='lower_bound')
    ax2.axvline(upper_bound, linestyle = '--',label='upper_bound')
    ax2.legend()
    ax2.set_xlabel(col,fontsize=20)
    ax2.annotate(f'{upper_bound:.0f}', xy=(upper_bound+10, 0.04), arrowprops=dict(arrowstyle="->", color='r', alpha=.8),fontsize=20)
    plt.show()  
OutlierDetection(df1,'Departure/Arrival time convenient')

# %%
#ANALYZING MINUTES OF DELAY

# %%
#UNDERSTANDING MINUTES OF DELAY OF 40 VALUES
var =df1['Departure Delay in Minutes'].values
var = np.sort(var,axis=None)
plt.plot(var[-40:-5])
plt.show()

# %%
def removal_outlier(data):
    #first lets know how how many rows are there in dataframe
    a=data.shape[0]
    print("{} are the number of row we have in our orginal dataframe".format(a))
    new_dataframe=data[(data['Flight Distance']<3995) & (data['Departure Delay in Minutes']<750) & (data['Arrival Delay in Minutes']<645)]
    #store the rows of filter dataframe
    b=new_dataframe.shape[0]
    #print the number of outliers
    print("Number of outliers:",(a-b))
    print("Percentage of data removed:",100-(b/a)*100)
    return new_dataframe
removal_outlier(df1)
# Out:
# 25976 are the number of row we have in our orginal dataframe
# Number of outliers: 122
# Percentage of data removed: 0.4696643055127794
#        Unnamed: 0     id  Gender      Customer Type  Age   Type of Travel  \
# 0               0  19556  Female     Loyal Customer   52  Business travel
# 1               1  90035  Female     Loyal Customer   36  Business travel
# 2               2  12360    Male  disloyal Customer   20  Business travel
# 3               3  77959    Male     Loyal Customer   44  Business travel
# 4               4  36875  Female     Loyal Customer   49  Business travel
# ...           ...    ...     ...                ...  ...              ...
# 25971       25971  78463    Male  disloyal Customer   34  Business travel
# 25972       25972  71167    Male     Loyal Customer   23  Business travel
# 25973       25973  37675  Female     Loyal Customer   17  Personal Travel
# 25974       25974  90086    Male     Loyal Customer   14  Business travel
# ...
